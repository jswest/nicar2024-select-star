# %% [markdown]
# # SELECT * FROM interesting

# %%
import pandas as pd # For data maniuplation.
import torch # A lower-level machine learning library.
import transformers # A higher-level machine learning library.

# %%
df = pd.read_csv("./../data/index.csv")

# %%
df
# Out:
#                                        id  \
# 0     http://www.loc.gov/item/2017780428/
# 1     http://www.loc.gov/item/2017780568/
# 2     http://www.loc.gov/item/2017780627/
# 3     http://www.loc.gov/item/2017780628/
# 4     http://www.loc.gov/item/2017780430/
# ...                                   ...
# 1995  http://www.loc.gov/item/2017827716/
# 1996  http://www.loc.gov/item/2017827717/
# 1997  http://www.loc.gov/item/2017827718/
# 1998  http://www.loc.gov/item/2017827719/
# 1999  http://www.loc.gov/item/2017827720/
#
#                                               image_url        date  \
# 0     https://tile.loc.gov/storage-services/service/...  1935-01-01
# 1     https://tile.loc.gov/storage-services/service/...  1935-01-01
# 2     https://tile.loc.gov/storage-services/service/...  1935-01-01
# 3     https://tile.loc.gov/storage-services/service/...  1935-01-01
# 4     https://tile.loc.gov/storage-services/service/...  1935-01-01
# ...
